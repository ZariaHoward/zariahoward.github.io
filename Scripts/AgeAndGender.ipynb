# %%
from PIL import Image
from PIL import ImageFilter
from PIL import ImageOps
from __future__ import print_function
import matplotlib.pyplot as plt
import numpy as np
from numpy.random import normal, uniform
from pymongo import MongoClient
from bson import ObjectId
client = MongoClient('localhost:27017')
db = client.Teenie

# %%
gaussian_numbers = normal(size=1000)
plt.hist(gaussian_numbers, bins=20, normed=True, cumulative=True)
plt.title("Gaussian Histogram")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %%
gaussian_numbers = normal(size=1000)
uniform_numbers = uniform(low=-3, high=3, size=1000)
plt.hist(gaussian_numbers, bins=20, histtype='stepfilled', normed=True, color='b', label='Gaussian')
plt.hist(uniform_numbers, bins=20, histtype='stepfilled', normed=True, color='r', alpha=0.5, label='Uniform')
plt.title("Gaussian/Uniform Histogram")
plt.xlabel("Value")
plt.ylabel("Probability")
plt.legend()
plt.show()

# %%
# histogram of ages by gender
print(db.Faces.find_one())
female_ages = []
male_ages = []
for post in db.Faces.find({"gender": "female"}):
    female_ages.append(post[u'age'])
for post in db.Faces.find({"gender": "male"}):
    male_ages.append(post[u'age'])
# Out:
# {u'underLipTop': {u'y': 676.9, u'x': 617.4}, u'noseTip': {u'y': 650.8, u'x': 623.9}, u'height': 69, u'upperLipBottom': {u'y': 666.7, u'x': 618.3}, u'noseLeftAlarTop': {u'y': 647.0, u'x': 613.9}, u'anger': 0.00132267515, u'pupilRight': {u'y': 642.1, u'x': 632.3}, u'fear': 0.0124991946, u'eyebrowLeftOuter': {u'y': 631.2, u'x': 591.4}, u'headPose_roll': 5.2, u'contempt': 0.00608798536, u'pupilLeft': {u'y': 637.0, u'x': 602.6}, u'sideburns': 0.5, u'eyeLeftBottom': {u'y': 637.9, u'x': 603.5}, u'top': 620, u'upperLipTop': {u'y': 664.4, u'x': 618.9}, u'eyeLeftInner': {u'y': 637.2, u'x': 608.5}, u'eyeLeftOuter': {u'y': 636.9, u'x': 598.3}, u'eyeRightInner': {u'y': 640.3, u'x': 628.9}, u'width': 69, u'eyeLeftTop': {u'y': 636.4, u'x': 603.6}, u'happiness': 0.112678669, u'disgust': 0.009398355, u'noseRightAlarOutTip': {u'y': 655.4, u'x': 630.6}, u'noseRightAlarTop': {u'y': 647.7, u'x': 627.4}, u'surprise': 0.165279865, u'beard': 0.4, u'eyebrowRightInner': {u'y': 630.3, u'x': 629.5}, u'noseLeftA
# ...

# %%
print(np.mean(female_ages))
print(np.mean(male_ages))
plt.hist(male_ages, bins=20, histtype='stepfilled', color='b',alpha=0.5, label='Male')
plt.hist(female_ages, bins=20, histtype='stepfilled', color='r', alpha=0.5, label='Female')
plt.title("Ages of Faces in the Teenie Harris Archive by Gender")
plt.xlabel("Ages")
plt.ylabel("Number of Faces")
plt.legend()
plt.show()
# Out:
# 34.4513340705
# 34.6311565382

# %%
female_happiness = []
female_anger = []
female_fear = []
female_surprise = []
female_disgust = []
female_sadness = []
female_neutral = []
male_happiness = []
male_anger = []
male_fear = []
male_surprise = []
male_disgust = []
male_sadness = []
male_neutral = []
male_ages = []
for post in db.Faces.find({"gender": "female"}):
    female_happiness.append(post[u'happiness'])
    female_anger.append(post[u'anger'])
    female_fear.append(post[u'fear'])
    female_surprise.append(post[u'surprise'])
    female_disgust.append(post[u'disgust'])
    female_sadness.append(post[u'sadness'])
    female_neutral.append(post[u'neutral'])
for post in db.Faces.find({"gender": "male"}):
    male_happiness.append(post[u'happiness'])
    male_anger.append(post[u'anger'])
    male_fear.append(post[u'fear'])
    male_surprise.append(post[u'surprise'])
    male_disgust.append(post[u'disgust'])
    male_sadness.append(post[u'sadness'])
    male_neutral.append(post[u'neutral'])

# %%
#did a log transform of the emotions that were difficult to see

plt.hist(male_happiness, bins=20, histtype='stepfilled', color='b',alpha=0.5, label='Male')
plt.hist(female_happiness, bins=20, histtype='stepfilled', color='r', alpha=0.5, label='Female')
plt.title("Happiness in the Teenie Harris Archive by Gender")
plt.xlabel("Probability Seen")
plt.ylabel("Number of Faces")
plt.legend()
plt.show()

plt.hist(male_anger, bins=20, histtype='stepfilled', color='b',alpha=0.5, label='Male',log = True)
plt.hist(female_anger, bins=20, histtype='stepfilled', color='r', alpha=0.5, label='Female',log = True)
plt.title("Anger in the Teenie Harris Archive by Gender")
plt.xlabel("Probability Seen")
plt.ylabel("Number of Faces")
plt.legend()
plt.show()

plt.hist(male_sadness, bins=20, histtype='stepfilled', color='b',alpha=0.5, label='Male',log = True)
plt.hist(female_sadness, bins=20, histtype='stepfilled', color='r', alpha=0.5, label='Female',log = True)
plt.title("Sadness in the Teenie Harris Archive by Gender")
plt.xlabel("Probability Seen")
plt.ylabel("Number of Faces")
plt.legend()
plt.show()

plt.hist(male_disgust, bins=20, histtype='stepfilled', color='b',alpha=0.5, label='Male',log = True)
plt.hist(female_disgust, bins=20, histtype='stepfilled', color='r', alpha=0.5, label='Female',log = True)
plt.title("Disgust in the Teenie Harris Archive by Gender")
plt.xlabel("Probability Seen")
plt.ylabel("Number of Faces")
plt.legend()
plt.show()

plt.hist(male_surprise, bins=20, histtype='stepfilled', color='b',alpha=0.5, label='Male',log = True)
plt.hist(female_surprise, bins=20, histtype='stepfilled', color='r', alpha=0.5, label='Female',log = True)
plt.title("Surprise in the Teenie Harris Archive by Gender")
plt.xlabel("Probability Seen")
plt.ylabel("Number of Faces")
plt.legend()
plt.show()

plt.hist(male_neutral, bins=20, histtype='stepfilled', color='b',alpha=0.5, label='Male')
plt.hist(female_neutral, bins=20, histtype='stepfilled', color='r', alpha=0.5, label='Female')
plt.title("Neutral in the Teenie Harris Archive by Gender")
plt.xlabel("Probability Seen")
plt.ylabel("Number of Faces")
plt.legend()
plt.show()

plt.hist(male_fear, bins=20, histtype='stepfilled', color='b',alpha=0.5, label='Male',log = True)
plt.hist(female_fear, bins=20, histtype='stepfilled', color='r', alpha=0.5, label='Female',log = True)
plt.title("Fear in the Teenie Harris Archive by Gender")
plt.xlabel("Probability Seen")
plt.ylabel("Number of Faces")
plt.legend()
plt.show()
