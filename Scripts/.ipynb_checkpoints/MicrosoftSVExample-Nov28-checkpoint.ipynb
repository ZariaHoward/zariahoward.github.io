# %% [markdown]
# # Project Oxford: Computer Vision API example

# %% [markdown]
# ### This Jupyter notebook shows you how to get started with the Project Oxford <b>Computer Vision API</b> in Python, and how to visualize your results.

# %% [markdown]
# To use this notebook, you will need to get keys to <b>Computer Vision API</b>. Visit <a href="http://www.projectoxford.ai/vision">www.projectoxford.ai/vision</a>, and then the “Try for free” button. On the “Sign in” page, use your Microsoft account to sign in and you will be able to subscribe to Computer Vision API and get free keys (Code of Conduct and TOS). After completing the sign-up process, paste your key into the variables section below. (Either the primary or the secondary key works.)

# %%
import time 
import requests
# import cv2
# import operator
import numpy as np
from __future__ import print_function

# Import library to display results
import matplotlib.pyplot as plt
# %matplotlib inline 
# Display images within Jupyter

import pickle
from pymongo import MongoClient
import pprint
import json as json_lib
import os
import Queue
import threading
# Out:
# /usr/local/lib/python2.7/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
# Variables
# used to be _url and _key
_cvurl = 'https://api.projectoxford.ai/vision/v1.0/analyze'
_faceurl = 'https://api.projectoxford.ai/face/v1.0/detect'
_emotiurl = 'https://api.projectoxford.ai/emotion/v1.0/recognize'
_cvkey ="insert_key_here"
_emotikey = "insert_key_here" 
_facekey = "insert_key_here" 
_maxNumRetries = 5
client = MongoClient('localhost:27017')
db = client.Teenie
curr_time = int(time.time())
num_requests_out = 0
api_rezults = {}
advanced_face_data = None
with open( "/Volumes/HueyFreeman/teenie-faces-1600.json", 'rb' ) as f:
    advanced_face_data = eval(f.read())
print(len(advanced_face_data))
# Out:
# 59278

# %% [markdown]
# ## Helper functions

# %%
def processRequest(request_type ,json, data, headers, params = None ):

    """
    Helper function to process the request to Project Oxford

    Parameters:
    json: Used when processing images from its URL. See API Documentation
    data: Used when processing image read from disk. See API Documentation
    headers: Used to pass the key information and the data type request
    """

    retries = 0
    result = None
    if request_type not in ["cv", "face", "emotion"] : return result
    while True:
        if request_type == "cv" :
            _url = _cvurl
            response = requests.request( 'post', _url, json = json, data = data, headers = headers, params = params )
        elif request_type == "face":
            _url = _faceurl
            response = requests.request( 'post', _url, json = json, data = data, headers = headers, params = params )
        else:
            _url = _emotiurl
            response = requests.request( 'post', _url, json = json, data = data, headers = headers)
            
            
        if response.status_code == 429: 

            print( "Message: %s" % ( response.json()) )

            if retries <= _maxNumRetries: 
                time.sleep(1) 
                retries += 1
                continue
            else: 
                print( 'Error: failed after retrying!' )
                break

        elif response.status_code == 200 or response.status_code == 201:

            if 'content-length' in response.headers and int(response.headers['content-length']) == 0: 
                result = None 
            elif 'content-type' in response.headers and isinstance(response.headers['content-type'], str): 
                if 'application/json' in response.headers['content-type'].lower(): 
                    result = response.json() if response.content else None 
                elif 'image' in response.headers['content-type'].lower(): 
                    result = response.content
        else:
            print( "Error code: %d" % ( response.status_code ) )
            print( "Message: %s" % ( response.json()) )

        break
        
    return result

# %% [markdown]
# ## Analysis of an image stored on disk

# %%
# Load raw image file into memory
def loadInDB(path):
    data = None 
    pathToFileInDisk = path
    if path == "!":
        print("failed")
        return
    with open( pathToFileInDisk, 'rb' ) as f:
        data = f.read()

    # Computer Vision parameters
    cvparams = { 'visualFeatures' : 'Categories,Tags,Description,Faces'} 
    faceparams = {'returnFaceId' : True, 'returnFaceLandmarks' : True, 'returnFaceAttributes':'age,gender,headPose,smile,facialHair,glasses'}
    #emotion api does not take parameters
    headers = dict()
    headers['Ocp-Apim-Subscription-Key'] = _cvkey
    headers['Content-Type'] = 'application/octet-stream'

    json = None

    result1 = processRequest("cv", json, data, headers, cvparams )
    headers['Ocp-Apim-Subscription-Key'] = _facekey
    ending = pathToFileInDisk[pathToFileInDisk.index("Box"):]
    i=0
    while (not advanced_face_data[i]['file'].endswith(ending)):
        i+=1
    photo_has_faces = len(advanced_face_data[i]['faces']) > 0
    if result1 is not None:
        if photo_has_faces:
            result2 = processRequest("face", json, data, headers, faceparams )
            headers['Ocp-Apim-Subscription-Key'] = _emotikey
            result3 = processRequest("emotion", json, data, headers)
        else:
            result2 = None
            result3 = None
    else:
        with open('/Volumes/HueyFreeman/microsoftlog.txt', 'a') as the_file:
                the_file.write('Photo unwritten: ' + path + '\n')

    #make a log of anything that results in none so that it can be retried
    if (result1 is not None):
        # pp = pprint.PrettyPrinter(depth=6,indent=4)
        # pp.pprint(result1)

        #Takes everything out of unicode
        result1 = eval(json_lib.dumps(result1))
        if result2 and result3: 
            result2 = eval(json_lib.dumps(result2))
            result3 = eval(json_lib.dumps(result3))

        new_data_point = {
                "path": pathToFileInDisk,
        }
        new_data_point["advancedFaceDetected"] = advanced_face_data[i]["faces"]
        if ('description' in result1) and ('captions' in result1['description']):
            cap_concatenated = " "
            for caption in result1['description']['captions']:
                cap_concatenated = caption['text'] + " " + cap_concatenated
            new_data_point["caption"] = cap_concatenated
        
        if ('description' in result1) and ('tags' in result1['description']):
            for tag in result1['description']['tags']:
                new_data_point[tag] = True
        if ('categories' in result1):
            for ind in result1['categories']:
                new_data_point[ind['name']] = ind['score']
        k = 0  
        try:
            obj_id = db.Photos.insert(new_data_point)
            obj_id_str = repr(obj_id).split("'")[1]  
        except:
            with open('/Volumes/HueyFreeman/microsoftlog.txt', 'a') as the_file:
                the_file.write('Photo unwritten: ' + path + '\n')
                the_file.write(repr(new_data_point))

        # type(result1['description']['tags'][1])
        # altered = eval(json.dumps(result1))
        # pp.pprint(eval(json.dumps(result3)))
        # pp.pprint(eval(json.dumps(result2)))
        #make one json for the face details
        if result3 and result2:
            for face in result3:
                for compare_face in result2:
                    try:
                        if ((face['faceRectangle']['left'] == compare_face['faceRectangle']['left']) and
                            (face['faceRectangle']['top'] == compare_face['faceRectangle']['top'])):
                            compare_face['scores'] = face['scores']
                    except:
                        with open('/Volumes/HueyFreeman/microsoftlog.txt', 'a') as the_file:
                             the_file.write('Erroneneous face data in photo: ' + path + '\n')
            face_obj_id_list = []

            for ind in result2:
                new_face_point = {} #instead of result2 set it equal to a list of object ids returned from mongodb
                new_face_point['photoId'] = obj_id
                try:
                    for dim in ind['faceRectangle']:
                        new_face_point[dim] = ind['faceRectangle'][dim]
                except:
                    pass
                try:
                    for emotion in ind['scores']:
                        new_face_point[emotion] = ind['scores'][emotion]
                except:
                    pass
                try:
                    for marks in ind['faceLandmarks']:
                        new_face_point[marks] = ind['faceLandmarks'][marks]
                except:
                    pass
                try:
                    new_face_point['age'] = ind['faceAttributes']['age']
                    new_face_point['beard'] = ind['faceAttributes']['facialHair']['beard']
                    new_face_point['moustache'] = ind['faceAttributes']['facialHair']['moustache']
                    new_face_point['sideburns'] = ind['faceAttributes']['facialHair']['sideburns']
                    new_face_point['gender'] = ind['faceAttributes']['gender']
                    new_face_point['smile'] = ind['faceAttributes']['smile']
                    new_face_point['headPose_pitch'] = ind['faceAttributes']['headPose']['pitch']
                    new_face_point['headPose_roll'] = ind['faceAttributes']['headPose']['roll']
                    new_face_point['headPose_yaw'] = ind['faceAttributes']['headPose']['yaw']
                except:
                    pass
                try:
                    face_obj_id = db.Faces.insert(new_face_point)
                    face_obj_id_list.append(face_obj_id)
                except:
                    try:
                        face_obj_id = db.Faces.insert(new_face_point)
                        face_obj_id_list.append(face_obj_id)
                    except:
                         with open('/Volumes/HueyFreeman/microsoftlog.txt', 'a') as the_file:
                            the_file.write('Face unwritten in photo: ' + path + '\n')
                            the_file.write(repr(new_face_point))
            try:
            # update a data point with the list of faces
                new = db.Photos.update({
                  '_id': obj_id
                },{
                  '$set': {
                    'face_data': face_obj_id_list
                  }
                }, upsert=False, multi=False)
                return 1
            except:
                with open('/Volumes/HueyFreeman/microsoftlog.txt', 'a') as the_file:
                    the_file.write('Faces list not updated in : '+ path + '\n')
                    the_file.write(repr(face_obj_id_list))
        else:
            print("Avoided unnecessary calls to api " + pathToFileInDisk)
            
    else: 
        print(pathToFileInDisk)
        with open('/Volumes/HueyFreeman/microsoftlog.txt', 'a') as the_file:
             the_file.write('Error in : '+ path + '\n')
        return 0

# %%
exitFlag = 0

class myThread (threading.Thread):
    def __init__(self, threadID, name, q):
        threading.Thread.__init__(self)
        self.threadID = threadID
        self.name = name
        self.q = q
    def run(self):
        print( "Starting " + self.name)
        process_data(self.name, self.q)
        print( "Exiting " + self.name)

def process_data(threadName, q):
    while not exitFlag:
        queueLock.acquire()
        if not workQueue.empty():
            data = q.get() #pulling out of namelist
            queueLock.release()
            loadInDB(data)
            print( "%s processing %s" % (threadName, data))
        else:
            queueLock.release()
        time.sleep(1)
#70,100 ...70 through 100 and 118 through 197
threadList = ["Thread-"+str(i) for i in xrange(12)] #maybe try only up to 72 max when you know it works
pathList = []
for i in xrange(80,85): #do (80, 100)
    cur_dir = "/Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_0" + str(i)
    for root, dirs, files in os.walk(cur_dir):
        pathList += [os.path.join(root, file) if file.endswith(".png") else "!" for file in files]
        #Give it the signal to abort in function if the path name isn't valid
queueLock = threading.Lock()
workQueue = Queue.Queue() #you want it to run about 100 times faster, or 600 calls per minute max
threads = []
threadID = 1


# Create new threads
for tName in threadList:
    thread = myThread(threadID, tName, workQueue)
    thread.start()
    threads.append(thread)
    threadID += 1

# Fill the queue
queueLock.acquire()
for the_path in pathList:
    workQueue.put(the_path)
queueLock.release()
print("workQueueLength = " + str(workQueue.qsize))

#something about having a long queue that won't allow it to run faster????

# Wait for queue to empty
while not workQueue.empty():
    pass

# Notify threads it's time to exit
exitFlag = 1

# Wait for all threads to complete
for t in threads:
    t.join()
print("Exiting Main Thread")
# Out:
# Starting Thread-0
# Starting Thread-1
# Starting Thread-2
# Starting Thread-3
# Starting Thread-4
# Starting Thread-5
# Starting Thread-6
# Starting Thread-7
# Starting Thread-8
# Starting Thread-9
# Starting Thread-10
# Starting Thread-11
# workQueueLength = <bound method Queue.qsize of <Queue.Queue instance at 0x19e9b6758>>
# Message: {u'message': u'Rate limit is exceeded. Try again in 1 seconds.', u'statusCode': 429}
# Message: {u'message': u'Rate limit is exceeded. Try again in 1 seconds.', u'statusCode': 429}
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12735.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12735.png
# Error code: 500
# Message: {u'message': u'Internal server error.', u'code': u'InternalServerError', u'requestId': u'4e0e9968-00c6-465c-8379-34f25d6abe15'}
# /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12731.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12731.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12730.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12738.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12741.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12736.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12740.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12733.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12729.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12734.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12743.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12743.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12739.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12745.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12747.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12747.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12744.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12749.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12749.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12750.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12746.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12732.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12752.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12753.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12748.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12751.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12754.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12755.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12767.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12767.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12756.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12758.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12758.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12761.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12761.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12760.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12765.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12766.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12772.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12772.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12762.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12757.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12768.png
# Error code: 500
# Message: {u'message': u'Internal server error.', u'code': u'InternalServerError', u'requestId': u'76f9fd45-3e9f-43a4-a20d-c00098bfbd26'}
# /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12776.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12776.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12771.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12778.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12778.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12779.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12779.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12774.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12773.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12777.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12775.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12775.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12780.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12782.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12783.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12781.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12785.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12784.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12784.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12786.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12790.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12787.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12796.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12796.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12789.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12788.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12794.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12791.png
# Error code: 500
# Message: {u'message': u'Internal server error.', u'code': u'InternalServerError', u'requestId': u'ba9bc91f-8c54-42d7-bac8-dd0f2806f6e8'}
# /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12799.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12799.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12795.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12792.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12792.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12793.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12798.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12802.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12802.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12797.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12803.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12810.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12810.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12801.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12804.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12800.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12811.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12811.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12805.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12806.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12807.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12808.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12814.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12812.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12817.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12820.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12820.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12824.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12818.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12821.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12826.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12827.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12829.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12830.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_080/12819.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12828.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12822.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12831.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12833.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12834.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12835.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12845.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12845.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12837.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12838.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12839.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12844.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12844.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12836.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12840.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12841.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12842.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12853.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12853.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12846.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12848.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12849.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12851.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12852.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12843.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12850.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12855.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12854.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12857.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12856.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12858.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12859.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12861.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12860.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12862.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12863.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12866.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12864.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12865.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12867.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12869.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12870.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12876.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12876.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12868.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12877.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12877.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12871.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12884.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12884.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12879.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12872.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12874.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12873.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12881.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12878.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12875.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12880.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12887.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12887.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12883.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12882.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12882.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12886.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12885.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12889.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12890.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12903.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12902.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12904.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12904.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12901.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12909.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12909.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12888.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12905.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12906.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12912.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12912.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12911.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12911.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12913.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12913.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12914.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12914.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12915.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12915.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12907.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12908.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_081/12910.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12958.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12957.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12960.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12960.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12966.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12963.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12963.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12967.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12964.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12961.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12962.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12965.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12968.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12959.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12969.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12977.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12977.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12971.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12979.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12979.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12970.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12974.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12982.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12982.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12972.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12972.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12973.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12981.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12981.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12975.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12975.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12976.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12978.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12986.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12986.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12983.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12980.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12985.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12987.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12984.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12994.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12994.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12990.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12989.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12995.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12995.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12991.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12992.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12988.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13001.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13001.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12993.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13002.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13002.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12996.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12997.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/12998.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13003.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13005.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13006.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13007.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13004.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13010.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13011.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13009.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13008.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13012.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13013.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13014.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13015.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13022.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13022.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13016.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13020.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13020.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13019.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13018.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13018.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13017.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13021.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13021.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13023.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13025.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13026.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13032.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13032.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13024.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13027.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13030.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13029.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13031.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13033.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13028.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13042.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13042.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13035.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13036.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13036.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13034.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13041.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13045.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13045.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13037.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13038.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_082/13038.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13047.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13049.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13048.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13051.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13044.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13052.pngThread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13043.png
#
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13050.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13053.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13054.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13056.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13055.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13064.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13064.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13057.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13065.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13065.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13058.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13059.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13060.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13060.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13062.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13063.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13061.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13066.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13066.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13067.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13068.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13069.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13071.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13071.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13072.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13072.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13073.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13073.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13070.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13074.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13075.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13076.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13077.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13078.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13079.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13081.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13088.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13122.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13122.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13093.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13096.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13083.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13080.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13101.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13119.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13123.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13121.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13120.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13153.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13153.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13152.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13154.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13157.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13158.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13156.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13156.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13159.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13160.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13162.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13155.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13161.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13163.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13166.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13165.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13167.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13168.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13170.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13169.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13175.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13175.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13171.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13164.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13174.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13172.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13173.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13176.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13176.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13182.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13182.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13177.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13178.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13183.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13183.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13186.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13186.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13188.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13188.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13180.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13179.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_083/13181.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13184.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13185.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13187.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13189.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13190.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13195.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13193.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13191.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13198.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13194.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13197.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13199.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13196.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13200.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13202.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13203.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13203.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13201.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13192.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13208.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13206.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13204.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13207.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13205.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13210.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13215.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13215.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13211.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13209.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13213.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13214.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13219.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13219.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13217.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13218.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13218.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13220.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13216.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13222.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13221.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13212.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13212.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13223.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13223.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13224.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13282.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13282.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13283.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13283.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13225.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13227.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13227.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13229.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13229.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13226.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13230.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13228.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13284.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13291.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13291.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13293.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13293.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13287.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13286.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13285.png
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13289.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13288.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13295.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13290.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13292.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13294.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13297.png
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13296.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13298.png
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13299.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13300.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13300.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13307.png
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13307.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13301.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13306.png
# Thread-8 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13306.png
# Thread-11 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13303.png
# Exiting Thread-8
# Exiting Thread-11
# Thread-5 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13302.png
# Thread-2 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13304.png
# Avoided unnecessary calls to api /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13308.png
# Thread-4 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13308.png
# Thread-0 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13305.png
# Exiting Thread-5
# Exiting Thread-2
# Exiting Thread-4
# Exiting Thread-0
# Thread-3 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13309.png
# Thread-1 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13310.png
# Thread-10 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13312.png
# Exiting Thread-3
# Thread-6 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13313.png
# Exiting Thread-1
# Exiting Thread-10
# Exiting Thread-6
# Thread-9 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13311.png
# Thread-7 processing /Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_084/13314.png
# Exiting Thread-9
# Exiting Thread-7
# Exiting Main Thread

# %%
ex_b="/Users/zariahoward/Desktop/Box_085/"
for i in xrange(64,100):
    cur_dir = "/Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_0" + str(i)
    for root, dirs, files in os.walk(cur_dir):
        for file in files:
            if file.endswith(".png"):
                print(os.path.join(root, file))
                print(loadInDB(os.path.join(root, file))) 

# print(db.Photos.find_one(obj_id)) #you must retrieve by the object id returned to you

'''
>> import pymongo
>>> conn = pymongo.MongoClient()
>>> db = conn.test #test is my database
>>> col = db.spam #Here spam is my collection
>>> cur = col.find()  
>>> cur
<pymongo.cursor.Cursor object at 0xb6d447ec>
>>> for doc in cur:
...     print(doc)
... 
{'a': 1, '_id': ObjectId('54ff30faadd8f30feb90268f'), 'b': 2}
{'a': 1, 'c': 3, '_id': ObjectId('54ff32a2add8f30feb902690'), 'b': 2}
'''

# %%
for i in xrange(55,56):
    cur_dir = "/Volumes/HueyFreeman/Teenie_Harris_PNG1024/Box_0" + str(i)
    for root, dirs, files in os.walk(cur_dir):
        for file in files:
            if file.endswith(".png"):
                if (int(file[0:4]) > 7377):
                    print(os.path.join(root, file))
                    print(loadInDB(os.path.join(root, file)))
